# %% [markdown]
# <a href="https://colab.research.google.com/github/lghwan/EBlghwan/blob/main/1208F_finished_Q.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# 엑셀파일 소환

# %%
df = pd.read_excel('/content/sample_data/weather.xlsx')
df
# Out:
#            날짜  평균기온  최저기온  최고기온
# 0  2022-06-01  22.1  16.2  28.6
# 1  2022-06-02  21.5  17.1  26.9
# 2  2022-06-03  24.5  18.7  32.6
# 3  2022-06-04  25.6  20.3  29.7
# 4  2022-06-05  22.7  20.2  27.0
# 5  2022-06-06  19.7  16.7  24.5
# 6  2022-06-07  20.6  15.1  25.1
# 7  2022-06-08  21.2  16.2  25.8
# 8  2022-06-09  20.9  18.5  24.5
# 9  2022-06-10  20.9  17.2  26.6
# 10 2022-06-11  24.6  17.7  32.7
# 11 2022-06-12  24.6  18.9  31.5
# 12 2022-06-13  23.6  19.6  29.2
# 13 2022-06-14  21.5  17.7  27.1
# 14 2022-06-15  17.5  14.9  20.1
# 15 2022-06-16  20.3  17.6  24.8
# 16 2022-06-17  22.5  16.5  28.1
# 17 2022-06-18  23.3  22.0  25.1
# 18 2022-06-19  23.4  22.3  25.1
# 19 2022-06-20  25.2  22.0  29.0
# 20 2022-06-21  26.5  21.2  32.6
# 21 2022-06-22  25.9  21.9  31.0
# 22 2022-06-23  24.3  23.3  26.4
# 23 2022-06-24  22.6  20.6  24.9
# 24 2022-06-25  26.0  21.5  30.5
# 25 2022-06-26  26.5  24.8  28.1
# 26 2022-06-27  26.8  25.4  28.1
# 27 2022-06-28  26.9  25.7  27.9
# ...

# %% [markdown]
# 컬럼 정보 출력

# %%
df._________
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      30 non-null     datetime64[ns]
#  1   평균기온    30 non-null     float64
#  2   최저기온    30 non-null     float64
#  3   최고기온    30 non-null     float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 1.1 KB

# %%
df._________
# Out:
# Index(['날짜', '평균기온', '최저기온', '최고기온'], dtype='object')

# %% [markdown]
# 특정 컬럼 선택

# %%
#평균기온 컬럼만 출력

df[_________]
# Out:
# 0     22.1
# 1     21.5
# 2     24.5
# 3     25.6
# 4     22.7
# 5     19.7
# 6     20.6
# 7     21.2
# 8     20.9
# 9     20.9
# 10    24.6
# 11    24.6
# 12    23.6
# 13    21.5
# 14    17.5
# 15    20.3
# 16    22.5
# 17    23.3
# 18    23.4
# 19    25.2
# 20    26.5
# 21    25.9
# 22    24.3
# 23    22.6
# 24    26.0
# 25    26.5
# 26    26.8
# 27    26.9
# 28    25.1
# 29    22.3
# Name: 평균기온, dtype: float64

# %%
#최고기온 컬럼의 30이상의 자료 출력

df.loc[df[__________________
# Out:
#            날짜  평균기온  최저기온  최고기온
# 2  2022-06-03  24.5  18.7  32.6
# 10 2022-06-11  24.6  17.7  32.7
# 11 2022-06-12  24.6  18.9  31.5
# 20 2022-06-21  26.5  21.2  32.6
# 21 2022-06-22  25.9  21.9  31.0
# 24 2022-06-25  26.0  21.5  30.5

# %%
#불 인덱싱 활용하여 최고기온 30 이상의 자료 출력

w=df['최고기온']>=30
_________
# Out:
#            날짜  평균기온  최저기온  최고기온
# 2  2022-06-03  24.5  18.7  32.6
# 10 2022-06-11  24.6  17.7  32.7
# 11 2022-06-12  24.6  18.9  31.5
# 20 2022-06-21  26.5  21.2  32.6
# 21 2022-06-22  25.9  21.9  31.0
# 24 2022-06-25  26.0  21.5  30.5

# %%
#최고기온 컬럼의 조건 지정 후 날짜 및 평균기온 컬럼 출력

df.loc[df['최고기온']>=30,__________________]
# Out:
#            날짜  평균기온
# 2  2022-06-03  24.5
# 10 2022-06-11  24.6
# 11 2022-06-12  24.6
# 20 2022-06-21  26.5
# 21 2022-06-22  25.9
# 24 2022-06-25  26.0

# %%
# loc 함수를 이용하여 행의 부분 지정

df.loc[_________,['날짜','평균기온']]
# Out:
#           날짜  평균기온
# 0 2022-06-01  22.1
# 1 2022-06-02  21.5
# 2 2022-06-03  24.5
# 3 2022-06-04  25.6
# 4 2022-06-05  22.7
# 5 2022-06-06  19.7

# %%
#불 인덱싱 활용 및 특정 컬럼 지정

w=df['최고기온']>=30
df[w][[__________________]]
# Out:
#            날짜  평균기온
# 2  2022-06-03  24.5
# 10 2022-06-11  24.6
# 11 2022-06-12  24.6
# 20 2022-06-21  26.5
# 21 2022-06-22  25.9
# 24 2022-06-25  26.0

# %%
# 특정 컬럼의 최고 숫치 지정 및 전체 행 데이터 프레임 형태로 출력
v=df['평균기온']___df['평균기온'].max()
_________
# Out:
#            날짜  평균기온  최저기온  최고기온
# 27 2022-06-28  26.9  25.7  27.9

# %%
# df[v]와 v 출력 사항 비교

v
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 28    False
# 29    False
# Name: 평균기온, dtype: bool

# %% [markdown]
# 데이터 가공

# %%
# 최저기온 컬럼 삭제 후 원본 데이터세트 변환
# 데이터프레임 컬럼 이름 변화 확인

df.drop(['최저기온'],axis=1, inplace=True)
df.columns
# Out:
# Index(['날짜', '평균기온', '최고기온'], dtype='object')

# %%
# 데이터프레임 컬럼 이름 변화 (한글 -> 영문)
# sns plotting 시 필요

df.columns=['Date','Temperature_avg','Temperature_max']
df.head()
# Out:
#         Date  Temperature_avg  Temperature_max
# 0 2022-06-01             22.1             28.6
# 1 2022-06-02             21.5             26.9
# 2 2022-06-03             24.5             32.6
# 3 2022-06-04             25.6             29.7
# 4 2022-06-05             22.7             27.0

# %%
#컬럼별 데이터 타입 확인

df._________
# Out:
# Date               datetime64[ns]
# Temperature_avg           float64
# Temperature_max           float64
# dtype: object

# %% [markdown]
# 컬럼생성

# %%
df['년도']=df['Date'].dt.year
df['월']=df['Date'].dt.month
df['일']=df['Date'].dt.day
df.head()
# Out:
#         Date  Temperature_avg  Temperature_max    년도  월  일
# 0 2022-06-01             22.1             28.6  2022  6  1
# 1 2022-06-02             21.5             26.9  2022  6  2
# 2 2022-06-03             24.5             32.6  2022  6  3
# 3 2022-06-04             25.6             29.7  2022  6  4
# 4 2022-06-05             22.7             27.0  2022  6  5

# %% [markdown]
# Seaborn Dataset 소환 (Penguins) 및 결측데이터 처리

# %%
import seaborn as sns

# %%
penguins = sns.load_dataset('penguins')
print(penguins)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# print(penguins) 와 penguins 차이 비교

penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
#결측데이터 확인

penguins._________
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
# 'sex' 컬럼 삭제 후 컬럼 이름 확인

penguins.drop('sex',axis=1,inplace=True)
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g'],
#       dtype='object')

# %%
# body_mass_g 의 최빈값 확인

penguins['body_mass_g']._________
# Out:
# 0    3800.0
# Name: body_mass_g, dtype: float64

# %%
# 최빈값으로 NaN 데이터 채우기

penguins['body_mass_g']._________(penguins['body_mass_g'].mode()[0],inplace=True)

# %%
penguins.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       2
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          0
# dtype: int64

# %%
penguins.head(20)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
# 'island' 컬럼의 'Torgersen' , 'species' 컬럼의 'Adelie' 항목만 선택해서 출력

conditions=(penguins['island']=='Torgersen') ___ (penguins['species']=='Adelie')
penguins[_________].head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g
# 0       3750.0
# 1       3800.0
# 2       3250.0
# 3       3800.0
# 4       3450.0

# %%
# penguins 데이터 프레임에서 'species' 분류에 따른 'body_mass_g' 컬럼의 평균값 구하기

pd.DataFrame(penguins._________('species')._________['body_mass_g'])
# Out:
# <ipython-input-28-b46364ed7365>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.DataFrame(penguins.groupby('species').mean()['body_mass_g'])
#            body_mass_g
# species
# Adelie     3701.315789
# Chinstrap  3733.088235
# Gentoo     5065.725806

# %%
# penguins 데이터프레임의 컬럼별 'species' 자료 갯수 확인
penguins=penguins.groupby(['species'])._________
penguins
# Out:
#            island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species
# Adelie        152             151            151                151
# Chinstrap      68              68             68                 68
# Gentoo        124             123            123                123
#
#            body_mass_g
# species
# Adelie             152
# Chinstrap           68
# Gentoo             124

# %% [markdown]
# Seaborn Dataset 소환 (Planets) 및 결측데이터 처리

# %%
import pandas as pd
import seaborn as sns

planets = sns.load_dataset('planets')

print(planets)
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
# 컬럼별 데이터 종류 확인
planets._________
# Out:
# method             object
# number              int64
# orbital_period    float64
# mass              float64
# distance          float64
# year                int64
# dtype: object

# %%
# method 컬럼에서 Radial Velocity 항목만 출력
# 상위 10개 행 출력

conditions=planets['method'].isin(['______________'])
planets[conditions].head(10)
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009
# 5  Radial Velocity       1         185.840   4.80     76.39  2008
# 6  Radial Velocity       1        1773.400   4.64     18.15  2002
# 7  Radial Velocity       1         798.500    NaN     21.41  1996
# 8  Radial Velocity       1         993.300  10.30     73.10  2008
# 9  Radial Velocity       2         452.800   1.99     74.79  2010

# %%
# 데이터프레임 mass 기준으로 내림차순 정렬

planets.sort_values('mass',ascending=_________).head()
# Out:
#               method  number  orbital_period   mass  distance  year
# 321  Radial Velocity       1         2371.00  25.00     37.05  2008
# 85   Radial Velocity       2          379.63  21.42       NaN  2009
# 63   Radial Velocity       1          305.50  20.60     92.51  2013
# 913  Radial Velocity       1          677.80  19.80       NaN  2007
# 3    Radial Velocity       1          326.03  19.40    110.62  2007

# %%
# distance 컬럼의 최빈값 출력

planets['distance']._________
# Out:
# 0    780.0
# Name: distance, dtype: float64

# %%
# distance 컬럼의 NaN 데이터 최빈값으로 대체
# 원 데이터 변환

planets['distance']._________(planets['distance']._________,inplace=True)

# %%
# 컬럼별 결측데이터 재확인
planets._________
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance            0
# year                0
# dtype: int64

# %%
# mass 컬럼의 최빈값 출력

planets[________].mode()
# Out:
# 0    1.8
# 1    1.9
# Name: mass, dtype: float64

# %%
# mass 컬럼의 NaN 데이터 인덱싱 0 최빈값으로 대체
# 원 데이터 변환

planets['mass'].fillna(planets['mass']._________,inplace=True)

# %%
# 'orbital_period' 컬럼의 최빈값 출력

planets['orbital_period']._________
# Out:
# 0     123.0
# 1     428.5
# 2     883.0
# 3    1845.0
# Name: orbital_period, dtype: float64

# %%
# orbital_period 컬럼의 NaN 데이터 인덱싱 0 최빈값으로 출력
# 원 데이터 변환

planets['orbital_period']._______(planets['orbital_period']._________[0],inplace=_______)

# %%
#결측데이터 처리 결과 컬럼별로 확인
planets.isnull()._______
# Out:
# method            0
# number            0
# orbital_period    0
# mass              0
# distance          0
# year              0
# dtype: int64

# %%
#matplotlib 호출 후 pairplot 으로 시각화

import _________.pyplot as plt

sns._______(planets.head(50))
plt.suptitle('Pairwise Relationships')
plt.show()

# %%
# Box plot 으로 시각화

plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")
sns.________(x='number', y='mass', data=________, palette='pastel')
plt.title('Boxplot of Number of Planets and Mass')
plt.xlabel('Number of Planets')
plt.ylabel('Mass')
plt.show()

# %%
# violinplot으로 시각화
# pastel 팔레트 설정

plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")
sns._________(x='number', y='mass', data=planets, palette='______')
plt.title('Viloinplot of Mass for Number of Planets')
plt.xlabel('Number of Planets')
plt.ylabel('Mass')
plt.show()

# %%
# planet 데이터프레임의 mass 총 자료 갯수 파악
# hisplot 활용
# 커널밀도함수 On

plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")
sns._________(x='mass', data=planets, kde=______, color='skyblue')
plt.title('Planet Mass Count')
plt.show()

# %%
# mass 컬럼의 범위 >= 5로 설정 후 시각화

planets_mass_100 = planets[planets[______] >= ___]

plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")
sns.histplot(x='mass', data=planets_mass_100, kde=True, color='skyblue')
plt.title('Planet Mass Count, larger than 5.0')
plt.show()

# %%
# Scatterplot으로 Mass, Distance 분포 시각화
# planets Number에 따라 데이터 색깔 설정
# Planets Number 에 따른 mass, distance 분포 시각화

plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")
sns.________(x='mass', y='_______', data=planets, hue='______', palette='pastel')
plt.title('Scatter Plot of Distance vs. Mass of Planets')
plt.show()

# %%
# distance 컬럼의 자료 750 미만으로 설정 후 데이터프레임 planets_distance_750 으로 설정
# Scatterplot으로 distance 750 미만의 Planets Number 에 따른 distance - mass 분포 시각화
# 위의 scatterplot보다 상세한 사항 확인

planets_distance_750 = planets[planets[_______] <= 750]

plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")
sns.___________(x='mass', y='distance', data=planets_distance_750, hue='number', palette='pastel')
plt.title('Scatter Plot of Distance vs. Mass of Planets')
plt.show()
