# %% [markdown]
# <a href="https://colab.research.google.com/github/lghwan/EBlghwan/blob/main/1117_pdsns_Q_answer_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# isin() 함수 연습

# %%
import pandas as pd

# Creating a DataFrame with temperature and wind speed data
data = {'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05'],
        'Temperature (Celsius)': [20, 18, 25, 22, 19],
        'Wind Speed (km/h)': [15, 12, 20, 18, 16]}

weather_df = pd.DataFrame(data)

print(weather_df)
# Out:
#          Date  Temperature (Celsius)  Wind Speed (km/h)
# 0  2023-01-01                     20                 15
# 1  2023-01-02                     18                 12
# 2  2023-01-03                     25                 20
# 3  2023-01-04                     22                 18
# 4  2023-01-05                     19                 16

# %%
# .isin() 함수로 Date컬럼에서 특정 날짜의 rows 추출

selected_dates = ['2023-01-02', '2023-01-04', '2023-01-05']
selected_weather = weather_df[weather_df['Date'].isin(selected_dates)]

print(selected_weather)
# Out:
#          Date  Temperature (Celsius)  Wind Speed (km/h)
# 1  2023-01-02                     18                 12
# 3  2023-01-04                     22                 18
# 4  2023-01-05                     19                 16

# %%
#연습

# .isin() 함수로 Date컬럼에서 '2023-01-01' 자료만 추출
selected_dates = ['2023-01-01']
selected_weather = weather_df[weather_df['Date'].isin(selected_dates)]

print(selected_weather)
# Out:
#          Date  Temperature (Celsius)  Wind Speed (km/h)
# 0  2023-01-01                     20                 15

# %%
#연습

# .isin() 함수로 Date컬럼에서 '2023-01-01', '2023-01-02' 자료만 추출

selected_dates = ['2023-01-01', '2023-01-02']
selected_weather = weather_df[weather_df['Date'].isin(selected_dates)]

print(selected_weather)
# Out:
#          Date  Temperature (Celsius)  Wind Speed (km/h)
# 0  2023-01-01                     20                 15
# 1  2023-01-02                     18                 12

# %% [markdown]
# .fillna() 함수 연습

# %%
import pandas as pd
import numpy as np

# Creating a DataFrame with temperature and humidity data, including NaN values
data = {'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05'],
        'Temperature (Celsius)': [20, np.nan, 25, 22, 19],
        'Humidity (%)': [50, 60, np.nan, 55, np.nan]}

weather_df = pd.DataFrame(data)

# Using .fillna() to fill NaN values with specific values
# inplace = False, 원 데이터프레임을 바꾸지 않음.
filled_weather_df = weather_df.fillna({'Temperature (Celsius)': 0, 'Humidity (%)': 70}, inplace=False)

print("Original DataFrame:")
print(weather_df)
print("\nDataFrame after filling NaN values:")
print(filled_weather_df)
# Out:
# Original DataFrame:
#          Date  Temperature (Celsius)  Humidity (%)
# 0  2023-01-01                   20.0          50.0
# 1  2023-01-02                    NaN          60.0
# 2  2023-01-03                   25.0           NaN
# 3  2023-01-04                   22.0          55.0
# 4  2023-01-05                   19.0           NaN
#
# DataFrame after filling NaN values:
#          Date  Temperature (Celsius)  Humidity (%)
# 0  2023-01-01                   20.0          50.0
# 1  2023-01-02                    0.0          60.0
# 2  2023-01-03                   25.0          70.0
# 3  2023-01-04                   22.0          55.0
# 4  2023-01-05                   19.0          70.0

# %%
#연습

#isnull 활용, weather_df의 결측데이터 확인

weather_df[weather_df['Temperature (Celsius)'].isnull()]
# Out:
#          Date  Temperature (Celsius)  Humidity (%)
# 1  2023-01-02                    NaN          60.0

# %%
weather_df[weather_df['Humidity (%)'].isnull()]
# Out:
#          Date  Temperature (Celsius)  Humidity (%)
# 2  2023-01-03                   25.0           NaN
# 4  2023-01-05                   19.0           NaN

# %%
#연습

#isnull.sum 활용, weather_df의 컬럼별 결측데이터 총합 확인
weather_df.isnull().sum()
# Out:
# Date                     0
# Temperature (Celsius)    1
# Humidity (%)             2
# dtype: int64

# %%
#연습

# 위 데이터프레임 weather_df 의 결측데이터를 {'Temperature (Celsius)': 5, 'Humidity (%)': 50}로 대체.
# 원본데이터 변화 없음

import pandas as pd
import numpy as np

# Creating a DataFrame with temperature and humidity data, including NaN values
data = {'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05'],
        'Temperature (Celsius)': [20, np.nan, 25, 22, 19],
        'Humidity (%)': [50, 60, np.nan, 55, np.nan]}

weather_df = pd.DataFrame(data)

# Using .fillna() to fill NaN values with specific values
# inplace = False, 원 데이터프레임을 바꾸지 않음.
filled_weather_df = weather_df.fillna({'Temperature (Celsius)': 5, 'Humidity (%)': 50}, inplace=False)

print("Original DataFrame:")
print(weather_df)
print("\nDataFrame after filling NaN values:")
print(filled_weather_df)
# Out:
# Original DataFrame:
#          Date  Temperature (Celsius)  Humidity (%)
# 0  2023-01-01                   20.0          50.0
# 1  2023-01-02                    NaN          60.0
# 2  2023-01-03                   25.0           NaN
# 3  2023-01-04                   22.0          55.0
# 4  2023-01-05                   19.0           NaN
#
# DataFrame after filling NaN values:
#          Date  Temperature (Celsius)  Humidity (%)
# 0  2023-01-01                   20.0          50.0
# 1  2023-01-02                    5.0          60.0
# 2  2023-01-03                   25.0          50.0
# 3  2023-01-04                   22.0          55.0
# 4  2023-01-05                   19.0          50.0

# %%
import pandas as pd
import numpy as np

# Creating a DataFrame with temperature and humidity data, including NaN values
data = {'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05'],
        'Temperature (Celsius)': [20, np.nan, 25, 22, 19],
        'Humidity (%)': [50, 60, np.nan, 55, np.nan]}

weather_df = pd.DataFrame(data)

# Using .fillna() to fill NaN values with specific values
# inplace = False, 원 데이터프레임을 바꿈.

filled_weather_df = weather_df.fillna({'Temperature (Celsius)': 0, 'Humidity (%)': 70}, inplace=True)

print("Original DataFrame:")
print(weather_df)
print("\nDataFrame after filling NaN values:")
print(filled_weather_df)
# Out:
# Original DataFrame:
#          Date  Temperature (Celsius)  Humidity (%)
# 0  2023-01-01                   20.0          50.0
# 1  2023-01-02                    0.0          60.0
# 2  2023-01-03                   25.0          70.0
# 3  2023-01-04                   22.0          55.0
# 4  2023-01-05                   19.0          70.0
#
# DataFrame after filling NaN values:
# None

# %%
#연습

# 위 데이터프레임 weather_df 의 결측데이터를 {'Temperature (Celsius)': 5, 'Humidity (%)': 50}로 대체.
# 원본 데이터 자체를 변화
import pandas as pd
import numpy as np

# Creating a DataFrame with temperature and humidity data, including NaN values
data = {'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05'],
        'Temperature (Celsius)': [20, np.nan, 25, 22, 19],
        'Humidity (%)': [50, 60, np.nan, 55, np.nan]}

weather_df = pd.DataFrame(data)

# Using .fillna() to fill NaN values with specific values
# inplace = False, 원 데이터프레임을 바꿈.

filled_weather_df = weather_df.fillna({'Temperature (Celsius)': 5, 'Humidity (%)': 50}, inplace=True)

print("Original DataFrame:")
print(weather_df)
print("\nDataFrame after filling NaN values:")
print(filled_weather_df)
# Out:
# Original DataFrame:
#          Date  Temperature (Celsius)  Humidity (%)
# 0  2023-01-01                   20.0          50.0
# 1  2023-01-02                    5.0          60.0
# 2  2023-01-03                   25.0          50.0
# 3  2023-01-04                   22.0          55.0
# 4  2023-01-05                   19.0          50.0
#
# DataFrame after filling NaN values:
# None

# %% [markdown]
# Seabon 시각화 연습

# %%
import seaborn as sns

# Get a list of available datasets
dataset_names = sns.get_dataset_names()

# Print the list of dataset names
print(dataset_names)
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
import pandas as pd
import seaborn as sns

iris = sns.load_dataset('iris')

print(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#.dtypes 함수로 iris 데이터프레임 종류 확인하기
#float64를 가지는 컬럼은 몇개인가? 4개

iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
#연습
#Iris 의 결측데이터 확인 (자유롭게 코드 구상)

iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
#boxplot 으로 iris 시각화

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = sns.load_dataset('iris')

# Set the style of the plot
sns.set(style="whitegrid")

# Create a box plot for sepal length distribution by species
plt.figure(figsize=(10, 6))
sns.boxplot(x='species', y='sepal_length', data=iris)
plt.title('Sepal Length Distribution by Species')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.show()

# %%
# 연습

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = sns.load_dataset('iris')

#그리드 스타일 바꾸기
#whitegrid -> darkgrid
sns.set(style="darkgrid")

# plot 사이즈 조절
# (10, 6) 대신 (5, 3)으로 만들기
plt.figure(figsize=(5, 3))
sns.boxplot(x='species', y='sepal_length', data=iris)

# plot 제목, x축, y축 Capital letter 전환 (대문자로만 작성)
plt.title('SEPAL LENGTH DISTRIBUTION BY SPECIES')
plt.xlabel('SPECIES')
plt.ylabel('SEPAL LENGTH(CM)')
plt.show()

# %%
#Viloin으로 시각화
# The width of the violin at a particular value represents the density or frequency of data points at that value.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = sns.load_dataset('iris')

# Set the style of the plot
sns.set(style="whitegrid")

# Create a violin plot for sepal length distribution by species
plt.figure(figsize=(10, 6))
sns.violinplot(x='species', y='sepal_length', data=iris)
plt.title('Sepal Length Distribution by Species')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.show()

# %%
# 연습
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = sns.load_dataset('iris')

# Set the style of the plot
# style="dark" 설정
sns.set(style="dark")

# Create a violin plot for sepal length distribution by species
# 기존 사이즈의 1/2 배 (축소)
plt.figure(figsize=(5, 3))
sns.violinplot(x='species', y='sepal_length', data=iris)
# plot 제목, x축, y축 Capital letter 전환 (대문자로만 작성)
plt.title('SEPAL LENGTH DISTRIBUTION BY SPECIES')
plt.xlabel('SPECIES')
plt.ylabel('SEPAL LENGTH(CM)')
plt.show()

# %%
#scatter함수 파악
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = sns.load_dataset('iris')

# Set the style of the plot
sns.set(style="whitegrid")

# Create a scatter plot for sepal length vs. sepal width
plt.figure(figsize=(10, 6))
sns.scatterplot(x='sepal_length', y='sepal_width', hue='species', data=iris, palette='Set1')
plt.title('Scatter Plot of Sepal Length vs. Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
#연습

import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = sns.load_dataset('iris')

# Set the style of the plot
# darkgrid 로 변경
sns.set(style="darkgrid")

# Create a scatter plot for sepal length vs. sepal width
# 사이즈 1.2배 확대하기
plt.figure(figsize=(12, 7.2))

#x, y축 바꿔서 plotting
sns.scatterplot(x='sepal_width', y='sepal_length', hue='species', data=iris, palette='Set1')

#plot 제목, x축, y축 Capital letter 전환 (대문자로만 작성)
plt.title('SCATTER PLOT OF SEPAL LENGTH VS. SEPAL WIDTH')
plt.xlabel('SEPAL LENGTH(CM)')
plt.ylabel('SEPAL WIDTH(CM)')
plt.show()

# %%
#추가연습
# seaborn dataset에서 'planets' dataset 로드

import pandas as pd
import seaborn as sns

planets = sns.load_dataset('planets')

print(planets)
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
#추가 연습
# planets 데이터프레임 컬럼별 결측데이터 확인

planets.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
#추가연습
#planets 데이터프레임에서 결측데이터가 가장 많은 컬럼 삭제

planets.drop('mass',axis=1,inplace=True)

# %%
#추가 연습
# mass 삭제 후 column 이름 확인
#.colums 함수 사용
planets.columns
# Out:
# Index(['method', 'number', 'orbital_period', 'distance', 'year'], dtype='object')

# %%
#추가 연습
#'distance' 컬럼 최빈값 출력
planets['distance'].mode()
# Out:
# 0    780.0
# Name: distance, dtype: float64

# %%
#추가 연습
# planets 데이터프레임 distance 컬럼 결측데이터 최빈값으로 수정
# 제일 마지막 행 5개 출력 .tail 사용

planets['distance'].fillna(planets['distance'].mode()[0],inplace=True)
planets.tail()
# Out:
#        method  number  orbital_period  distance  year
# 1030  Transit       1        3.941507     172.0  2006
# 1031  Transit       1        2.615864     148.0  2007
# 1032  Transit       1        3.191524     174.0  2007
# 1033  Transit       1        4.125083     293.0  2008
# 1034  Transit       1        4.187757     260.0  2008

# %%
#barplot으로 시각화

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the "planets" dataset
planets = sns.load_dataset('planets')

# Set the style of the plot
sns.set(style="whitegrid")

# Count the number of planets discovered each year
planet_count_by_year = planets['year'].value_counts().reset_index().rename(columns={'year': 'planet_count', 'index': 'discovery_year'})

# Create a bar plot for the number of planets discovered each year
plt.figure(figsize=(12, 6))
sns.barplot(x='discovery_year', y='planet_count', data=planet_count_by_year, palette='viridis')
plt.title('Number of Planets Discovered Each Year')
plt.xlabel('Discovery Year')
plt.ylabel('Number of Planets Discovered')
plt.show()

# %%
#barplot으로 시각화2

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the "planets" dataset
planets = sns.load_dataset('planets')

# Set the style of the plot
sns.set(style="darkgrid")

# Count the number of planets discovered each year
planet_count_by_year = planets['year'].value_counts().reset_index().rename(columns={'year': 'planet_count', 'index': 'discovery_year'})

# Create a bar plot for the number of planets discovered each year
plt.figure(figsize=(12, 4))
plt.rc('axes', titlesize=10)
sns.barplot(x='discovery_year', y='planet_count', data=planet_count_by_year, palette='viridis')
plt.title('Number of Planets Discovered Each Year')
plt.xlabel('Discovery Year')
plt.ylabel('Number of Planets Discovered')
plt.show()

# %%
#데이터 프레임 호출 후 python 추천 그래프 확인
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
# ...

# %%
from matplotlib import pyplot as plt
planets.plot(kind='scatter', x='distance', y='year', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
